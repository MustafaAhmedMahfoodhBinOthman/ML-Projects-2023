# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./archive_7/heart_attack_prediction_dataset.csv')
df
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               0        1        0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
df.describe()
# Out:
#           Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# count 8763.00      8763.00     8763.00   8763.00         8763.00  8763.00
# mean    53.71       259.88       75.02      0.65            0.49     0.90
# std     21.25        80.86       20.55      0.48            0.50     0.30
# min     18.00       120.00       40.00      0.00            0.00     0.00
# 25%     35.00       192.00       57.00      0.00            0.00     1.00
# 50%     54.00       259.00       75.00      1.00            0.00     1.00
# 75%     72.00       330.00       93.00      1.00            1.00     1.00
# max     90.00       400.00      110.00      1.00            1.00     1.00
#
#        Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.00              8763.00                  8763.00
# mean      0.50                 0.60                    10.01
# std       0.50                 0.49                     5.78
# ...

# %%
df_corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,7))
sns.heatmap(df_corr, annot=False, )
plt.show()

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
for i in df.columns:
    if len(df[i].unique()) < 21:
        plt.subplots()
        sns.countplot(data=df, x=df[i])
        plt.title(f'{i}')
        plt.show()

# %%
for i in df.columns:
    if len(df[i].unique()) > 21:
        plt.subplots()
        sns.histplot(data=df, x=df[i])
        plt.title(f'{i}')
        plt.show()

# %% [markdown]
# # Preprocessing

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print(i)
# Out:
# Patient ID
# Sex
# Blood Pressure
# Diet
# Country
# Continent
# Hemisphere

# %%
for i in df.columns:
    if df[i].dtype != 'object':
        print(i)
# Out:
# Age
# Cholesterol
# Heart Rate
# Diabetes
# Family History
# Smoking
# Obesity
# Alcohol Consumption
# Exercise Hours Per Week
# Previous Heart Problems
# Medication Use
# Stress Level
# Sedentary Hours Per Day
# Income
# BMI
# Triglycerides
# Physical Activity Days Per Week
# Sleep Hours Per Day
# Heart Attack Risk

# %%
objct = ['Patient ID',
'Sex',
'Blood Pressure',
'Diet',
'Country',
'Continent',
'Hemisphere',]

# %%
df[objct]
# Out:
#      Patient ID     Sex Blood Pressure       Diet         Country  \
# 0       BMW7812    Male         158/88    Average       Argentina
# 1       CZE1114    Male         165/93  Unhealthy          Canada
# 2       BNI9906  Female         174/99    Healthy          France
# 3       JLN3497    Male        163/100    Average          Canada
# 4       GFO8847    Male          91/88  Unhealthy        Thailand
# ...         ...     ...            ...        ...             ...
# 8758    MSV9918    Male          94/76    Healthy        Thailand
# 8759    QSV6764  Female        157/102    Healthy          Canada
# 8760    XKA5925    Male         161/75    Average          Brazil
# 8761    EPE6801    Male         119/67  Unhealthy          Brazil
# 8762    ZWN9666  Female         138/67    Healthy  United Kingdom
#
#           Continent           Hemisphere
# 0     South America  Southern Hemisphere
# 1     North America  Northern Hemisphere
# 2            Europe  Northern Hemisphere
# ...

# %%
print(df['Country'].unique())
print(df['Country'].value_counts())
# Out:
# ['Argentina' 'Canada' 'France' 'Thailand' 'Germany' 'Japan' 'Brazil'
#  'South Africa' 'United States' 'Vietnam' 'China' 'Italy' 'Spain' 'India'
#  'Nigeria' 'New Zealand' 'South Korea' 'Australia' 'Colombia'
#  'United Kingdom']
# Country
# Germany           477
# Argentina         471
# Brazil            462
# United Kingdom    457
# Australia         449
# Nigeria           448
# France            446
# Canada            440
# China             436
# New Zealand       435
# Japan             433
# Italy             431
# Spain             430
# Colombia          429
# Thailand          428
# South Africa      425
# Vietnam           425
# United States     420
# India             412
# South Korea       409
# Name: count, dtype: int64

# %%
print(df['Diet'].unique())
print(df['Diet'].value_counts())
# Out:
# ['Average' 'Unhealthy' 'Healthy']
# Diet
# Healthy      2960
# Average      2912
# Unhealthy    2891
# Name: count, dtype: int64

# %%
print(df['Continent'].unique())
print(df['Continent'].value_counts())
# Out:
# ['South America' 'North America' 'Europe' 'Asia' 'Africa' 'Australia']
# Continent
# Asia             2543
# Europe           2241
# South America    1362
# Australia         884
# Africa            873
# North America     860
# Name: count, dtype: int64

# %%
print(df['Hemisphere'].unique())
print(df['Hemisphere'].value_counts())
# Out:
# ['Southern Hemisphere' 'Northern Hemisphere']
# Hemisphere
# Northern Hemisphere    5660
# Southern Hemisphere    3103
# Name: count, dtype: int64

# %%
df['Blood Pressure']
# Out:
# 0        158/88
# 1        165/93
# 2        174/99
# 3       163/100
# 4         91/88
#          ...
# 8758      94/76
# 8759    157/102
# 8760     161/75
# 8761     119/67
# 8762     138/67
# Name: Blood Pressure, Length: 8763, dtype: object

# %%
df[['BP_systolic', 'BP_diastolic']] = df['Blood Pressure'].str.split('/', expand=True)

df['BP_systolic'] = pd.to_numeric(df['BP_systolic'])
df['BP_diastolic'] = pd.to_numeric(df['BP_diastolic'])

# %%
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...   BMI  Triglycerides  \
# 0               0        1        0  ... 31.25            286
# 1               1        1        1  ... 27.19            235
# 2               0        0        0  ... 28.18            587
# 3               1        1        0  ... 36.46            378
# 4               1        1        1  ... 21.81            231
#
#   Physical Activity Days Per Week  Sleep Hours Per Day    Country  \
# ...

# %%
df = df.drop(columns='Patient ID', axis=1)

# %%
df = df.drop(columns='Blood Pressure', axis=1)

# %%
df.head()
# Out:
#    Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0   67    Male          208          72         0               0        1
# 1   21    Male          389          98         1               1        1
# 2   21  Female          324          72         1               0        0
# 3   84    Male          383          73         1               1        1
# 4   66    Male          318          93         1               1        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...   BMI  \
# 0        0                    0                     4.17  ... 31.25
# 1        1                    1                     1.81  ... 27.19
# 2        0                    0                     2.08  ... 28.18
# 3        0                    1                     9.83  ... 36.46
# 4        1                    0                     5.80  ... 21.81
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
print(df['Diet'].unique())
print(df['Diet'].value_counts())
# Out:
# ['Average' 'Unhealthy' 'Healthy']
# Diet
# Healthy      2960
# Average      2912
# Unhealthy    2891
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Cholesterol', 'Heart Rate', 'Diabetes', 'Family History',
#        'Smoking', 'Obesity', 'Alcohol Consumption', 'Exercise Hours Per Week',
#        'Diet', 'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere', 'Heart Attack Risk', 'BP_systolic',
#        'BP_diastolic'],
#       dtype='object')

# %%
df = df[['Age', 'Sex', 'BP_systolic', 'BP_diastolic','Cholesterol',  'Heart Rate', 'Diabetes',
       'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption',
       'Exercise Hours Per Week', 'Diet', 'Previous Heart Problems',
       'Medication Use', 'Stress Level', 'Sedentary Hours Per Day', 'Income',
       'BMI', 'Triglycerides', 'Physical Activity Days Per Week',
       'Sleep Hours Per Day', 'Country', 'Continent', 'Hemisphere',
       'Heart Attack Risk', ]]

# %%
df.head()
# Out:
#    Age     Sex  BP_systolic  BP_diastolic  Cholesterol  Heart Rate  Diabetes  \
# 0   67    Male          158            88          208          72         0
# 1   21    Male          165            93          389          98         1
# 2   21  Female          174            99          324          72         1
# 3   84    Male          163           100          383          73         1
# 4   66    Male           91            88          318          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                     6.62  261404
# 1               1        1        1  ...                     4.96  285768
# 2               0        0        0  ...                     9.46  235282
# 3               1        1        0  ...                     7.65  125640
# 4               1        1        1  ...                     1.51  160555
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = [
'Sex',
'Diet',
'Country',
'Continent',
'Hemisphere',]
for i in label:
    le = LabelEncoder().fit(df[i])
    df[i] = le.transform(df[i])

# %%
df.head()
# Out:
#    Age  Sex  BP_systolic  BP_diastolic  Cholesterol  Heart Rate  Diabetes  \
# 0   67    1          158            88          208          72         0
# 1   21    1          165            93          389          98         1
# 2   21    0          174            99          324          72         1
# 3   84    1          163           100          383          73         1
# 4   66    1           91            88          318          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                     6.62  261404
# 1               1        1        1  ...                     4.96  285768
# 2               0        0        0  ...                     9.46  235282
# 3               1        1        0  ...                     7.65  125640
# 4               1        1        1  ...                     1.51  160555
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              8763 non-null   int64
#  1   Sex                              8763 non-null   int32
#  2   BP_systolic                      8763 non-null   int64
#  3   BP_diastolic                     8763 non-null   int64
#  4   Cholesterol                      8763 non-null   int64
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
for i in df.columns:
    if len(df[i].unique()) < 21:
        plt.subplots()
        sns.countplot(data=df, x=df[i])
        plt.title(f'{i}')
        plt.show()

# %%
for i in df.columns:
    if len(df[i].unique()) < 21:
        plt.subplots()
        sns.countplot(data=df, x=df[i], hue='Heart Attack Risk')
        plt.title(f'{i}')
        plt.show()

# %%
from sklearn.utils import resample
import pandas as pd

# Assuming 'df' is your DataFrame with 'Heart Attack Risk' as the target variable
df_majority = df[df['Heart Attack Risk'] == 0]
df_minority = df[df['Heart Attack Risk'] == 1]

oversampled_minority = resample(df_minority,
                                 replace=True,  # Set to True for oversampling
                                 n_samples=len(df_majority),  # Match majority class size
                                 random_state=42)

df_balanced = pd.concat([df_majority, oversampled_minority])

# %%
df_balanced['Heart Attack Risk'].value_counts()
# Out:
# Heart Attack Risk
# 0    5624
# 1    5624
# Name: count, dtype: int64

# %%
for i in df_balanced.columns:
    if len(df_balanced[i].unique()) < 21:
        plt.subplots()
        sns.countplot(data=df_balanced, x=df_balanced[i], hue='Heart Attack Risk')
        plt.title(f'{i}')
        plt.show()

# %%
df = df_balanced

# %%
df['Heart Attack Risk'].value_counts()
# Out:
# Heart Attack Risk
# 0    5624
# 1    5624
# Name: count, dtype: int64

# %%
df_corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,7))
sns.heatmap(df_corr, annot=False, )
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df_copy = df.copy()

scaled_df = scaler.fit_transform(df_copy)

# %%
scale = pd.DataFrame(scaled_df, columns=df.columns)

# %%
scale.head()
# Out:
#    Age  Sex  BP_systolic  BP_diastolic  Cholesterol  Heart Rate  Diabetes  \
# 0 0.68 1.00         0.76          0.56         0.31        0.46      0.00
# 1 0.04 1.00         0.83          0.66         0.96        0.83      1.00
# 2 0.04 0.00         0.93          0.78         0.73        0.46      1.00
# 3 0.92 1.00         0.81          0.80         0.94        0.47      1.00
# 4 0.67 1.00         0.01          0.56         0.71        0.76      1.00
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0            0.00     1.00     0.00  ...                     0.55    0.86
# 1            1.00     1.00     1.00  ...                     0.41    0.95
# 2            0.00     0.00     0.00  ...                     0.79    0.77
# 3            1.00     1.00     0.00  ...                     0.64    0.38
# 4            1.00     1.00     1.00  ...                     0.13    0.50
#
# ...

# %%
scale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11248 entries, 0 to 11247
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Age                              11248 non-null  float64
#  1   Sex                              11248 non-null  float64
#  2   BP_systolic                      11248 non-null  float64
#  3   BP_diastolic                     11248 non-null  float64
#  4   Cholesterol                      11248 non-null  float64
#  5   Heart Rate                       11248 non-null  float64
#  6   Diabetes                         11248 non-null  float64
#  7   Family History                   11248 non-null  float64
#  8   Smoking                          11248 non-null  float64
#  9   Obesity                          11248 non-null  float64
#  10  Alcohol Consumption              11248 non-null  float64
# ...

# %%
scale['Heart Attack Risk'].unique()
# Out:
# array([0., 1.])

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import r2_score, confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
x = scale.drop([
    # 'Country','Continent', 'Hemisphere',
                'Heart Attack Risk','Income'], axis=1)
y = scale['Heart Attack Risk']

# %%
x.columns
# Out:
# Index(['Age', 'Sex', 'BP_systolic', 'BP_diastolic', 'Cholesterol',
#        'Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
#        'Alcohol Consumption', 'Exercise Hours Per Week', 'Diet',
#        'Previous Heart Problems', 'Medication Use', 'Stress Level',
#        'Sedentary Hours Per Day', 'BMI', 'Triglycerides',
#        'Physical Activity Days Per Week', 'Sleep Hours Per Day', 'Country',
#        'Continent', 'Hemisphere'],
#       dtype='object')

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3)

# %%
classifiers = [
    LogisticRegression(random_state=0),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    SVC(),
    XGBClassifier(),
    AdaBoostClassifier(random_state=42),
    GradientBoostingClassifier(criterion='squared_error',
                                      max_features='sqrt',
                                      random_state=42)
                                      
]

# %%
names = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVC', 'XGBoost', 'AdaBoost', 'GradientBoosting']

vlaues = []

for name, clf in zip(names, classifiers):
    clf.fit(x_train, y_train)
    result = clf.predict(x_test)
    score = clf.score(x_test, y_test)
    print( name ,accuracy_score(y_test, result))
    vlaues.append(score)
# Out:
# Logistic Regression 0.5211851851851852
# Decision Tree 0.7324444444444445
# Random Forest 0.8287407407407408
# SVC 0.5896296296296296
# XGBoost 0.7457777777777778
# AdaBoost 0.5336296296296297
# GradientBoosting 0.5712592592592592

# %%
plt.figure(figsize=(20,8))
sns.barplot(x=names,y=vlaues)
plt.xlabel('Models')
plt.ylabel('Accuracy %')
plt.title('Models and Accuracy')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import learning_curve

names = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'SVC', 'XGBoost']
values = []

for name, clf in zip(names, classifiers):
    train_sizes, train_scores, test_scores = learning_curve(
        clf, x_train, y_train, cv=5, scoring='accuracy', train_sizes=np.linspace(0.1, 1.0, 10), n_jobs=-1
    )

    train_scores_mean = np.mean(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)

    plt.figure()
    plt.title(f'Learning Curve - {name}')
    plt.xlabel('Training Examples')
    plt.ylabel('Score')
    plt.grid()

    plt.plot(train_sizes, train_scores_mean, 'o-', color='r', label='Training Score')
    plt.plot(train_sizes, test_scores_mean, 'o-', color='g', label='Cross-validation Score')

    plt.legend(loc='best')
    plt.show()

    print(f'{name} - Training Score: {train_scores_mean[-1]:.4f}, Cross-validation Score: {test_scores_mean[-1]:.4f}\n')

    values.append(test_scores_mean[-1])
# Out:
# Logistic Regression - Training Score: 0.5230, Cross-validation Score: 0.5032
# Decision Tree - Training Score: 1.0000, Cross-validation Score: 0.6980
# Random Forest - Training Score: 1.0000, Cross-validation Score: 0.7859
# SVC - Training Score: 0.7468, Cross-validation Score: 0.5782
# XGBoost - Training Score: 0.9952, Cross-validation Score: 0.7138
