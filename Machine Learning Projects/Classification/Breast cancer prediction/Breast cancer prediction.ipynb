# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./archive_7/data.csv')
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='diagnosis')
plt.show()

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# count   569.000000    569.000000  ...      569.000000               569.000000
# mean     14.127292     19.289649  ...        0.290076                 0.083946
# std       3.524049      4.301036  ...        0.061867                 0.018061
# min       6.981000      9.710000  ...        0.156500                 0.055040
# 25%      11.700000     16.170000  ...        0.250400                 0.071460
# 50%      13.370000     18.840000  ...        0.282200                 0.080040
# 75%      15.780000     21.800000  ...        0.317900                 0.092080
# max      28.110000     39.280000  ...        0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# 1. Diagnosis: This feature represents the diagnosis of breast cancer, with "M" indicating malignant (cancerous) and "B" indicating benign (non-cancerous).
# 2. Radius_mean: This feature represents the mean of distances from the center to points on the perimeter of the tumor.
# 3. Texture_mean: This feature represents the standard deviation of gray-scale values in the image, which describes the variation in the intensity of the tumor.
# 4. Perimeter_mean: This feature represents the mean size of the tumor's boundary.
# 5. Area_mean: This feature represents the mean area of the tumor.
# 6. Smoothness_mean: This feature represents the mean of local variation in radius lengths.
# 7. Compactness_mean: This feature represents the mean of the perimeter squared divided by the area - 1.0.
# 8. Concavity_mean: This feature represents the mean severity of concave portions of the contour.
# 9. Concave points_mean: This feature represents the mean number of concave portions of the contour.
# 10. Symmetry_mean: This feature represents the mean symmetry of the tumor.
# 11. Fractal_dimension_mean: This feature represents the mean "coastline approximation" - 1.
# 12. Radius_se: This feature represents the standard error of distances from the center to points on the perimeter of the tumor.
# 13. Texture_se: This feature represents the standard error of gray-scale values in the image.
# 14. Perimeter_se: This feature represents the standard error of the size of the tumor's boundary.
# 15. Area_se: This feature represents the standard error of the tumor's area.
# 16. Smoothness_se: This feature represents the standard error of local variation in radius lengths.
# 17. Compactness_se: This feature represents the standard error of the perimeter squared divided by the area - 1.0.
# 18. Concavity_se: This feature represents the standard error of the severity of concave portions of the contour.
# 19. Concave points_se: This feature represents the standard error of the number of concave portions of the contour.
# 20. Symmetry_se: This feature represents the standard error of the tumor's symmetry.
# 21. Fractal_dimension_se: This feature represents the standard error of the "coastline approximation" - 1.
# 22. Radius_worst: This feature represents the "worst" or largest mean value of distances from the center to points on the perimeter of the tumor.
# 23. Texture_worst: This feature represents the "worst" or largest mean value of gray-scale values in the image.
# 24. Perimeter_worst: This feature represents the "worst" or largest mean value of the size of the tumor's boundary.
# 25. Area_worst: This feature represents the "worst" or largest mean value of the tumor's area.
# 26. Smoothness_worst: This feature represents the "worst" or largest mean value of local variation in radius lengths.
# 27. Compactness_worst: This feature represents the "worst" or largest mean value of the perimeter squared divided by the area - 1.0.
# 28. Concavity_worst: This feature represents the "worst" or largest mean value of the severity of concave portions of the contour.
# 29. Concave points_worst: This feature represents the "worst" or largest mean value of the number of concave portions of the contour.
# 30. Symmetry_worst: This feature represents the "worst" or largest mean
# 31. Fractal_dimension_worst: This feature represents the "worst" or largest mean value of the fractal dimension of the tumor. Fractal dimension is a mathematical concept used to measure the complexity or irregularity of a shape. In the context of breast cancer prediction, it is used to quantify the complexity of the tumor's shape. A higher value of fractal dimension indicates a more irregular and complex tumor shape, which could potentially be associated with malignant (cancerous) tumors.

# %% [markdown]
# # EDA

# %%
df_corr = df.corr(numeric_only=True)

plt.figure(figsize=(20,10))
sns.heatmap(df_corr, annot=True)
plt.show()

# %%
numeric_columns = [column for column in df.columns if df[column].dtype == 'float64']
print(numeric_columns)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
for column in numeric_columns:
    plt.figure(figsize=(12,8))
    sns.kdeplot(data=df, x=column, hue='diagnosis', palette="crest", fill=True)
    plt.show()

# %%
df.head()
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %% [markdown]
# # Preprocessing

# %%
df = df.replace({'diagnosis': {'M': 1, 'B': 0}})

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, cross_val_score

# %%
x= df.drop('diagnosis', axis=1)
y = df['diagnosis']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
model = LazyClassifier(verbose=0, classifiers='all')
listofmodels, predictions = model.fit(x_train, x_test , y_train, y_test)

# %%
print(listofmodels)
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# CalibratedClassifierCV             0.98  ...        0.19
# LogisticRegression                 0.98  ...        0.12
# Perceptron                         0.98  ...        0.08
# SVC                                0.98  ...        0.10
# SGDClassifier                      0.98  ...        0.09
# LinearSVC                          0.97  ...        0.13
# KNeighborsClassifier               0.97  ...        1.54
# ExtraTreesClassifier               0.96  ...        0.68
# QuadraticDiscriminantAnalysis      0.96  ...        0.13
# PassiveAggressiveClassifier        0.96  ...        0.08
# AdaBoostClassifier                 0.96  ...        1.19
# XGBClassifier                      0.96  ...        0.82
# RidgeClassifier                    0.96  ...        0.11
# GaussianNB                         0.95  ...        0.08
# BaggingClassifier                  0.95  ...        0.53
# ...

# %%
import plotly.express as px
import plotly.io as pio

# %%
listofmodels.sort_values('Accuracy', inplace = True, ascending = False)
graph1 = px.line(listofmodels, y =['Accuracy'], markers = True)
graph1.update_xaxes(title = 'Model Approach')
graph1.update_yaxes(title = 'Accuracy of Model')
graph1.update_layout(title = 'Accuracy of Model Approaches', showlegend = True)
graph1.show()
