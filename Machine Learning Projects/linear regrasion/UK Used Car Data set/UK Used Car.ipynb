# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
df = pd.read_csv('./dataset/audi.csv')
df
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
# getting information about the features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %%
# is there any NULL values?
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
# how many cars models?
df['model'].unique()
# Out:
# array([' A1', ' A6', ' A4', ' A3', ' Q3', ' Q5', ' A5', ' S4', ' Q2',
#        ' A7', ' TT', ' Q7', ' RS6', ' RS3', ' A8', ' Q8', ' RS4', ' RS5',
#        ' R8', ' SQ5', ' S8', ' SQ7', ' S3', ' S5', ' A2', ' RS7'],
#       dtype=object)

# %% [markdown]
# # EDA

# %%
# the distrivution of cars models
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='model')
title = plt.title('Models distribution')
plt.show()

# %%
# years of the cars
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='year')
title = plt.title('Cars years')
plt.show()

# %%
# transmission types
sns.countplot(data=df, x='transmission')
title = plt.title('transmission types')
plt.show()

# %%
# fuel type
sns.countplot(data=df, x='fuelType')
title = plt.title('fuel type')
plt.show()

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
#histogram 
plt.figure(figsize=(10,8))
df.hist(bins=15)
plt.show()

# %%
# statistics
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
# the most expensive used car
price_max = df['price'].idxmax()
print(df.loc[price_max])
# Out:
# model                  R8
# year                 2020
# price              145000
# transmission    Semi-Auto
# mileage              2000
# fuelType           Petrol
# tax                   145
# mpg                  21.1
# engineSize            5.2
# Name: 4783, dtype: object

# %%
# the cheapest car
price_min = df['price'].idxmin()
print(df.loc[price_min])
# Out:
# model                  A3
# year                 2003
# price                1490
# transmission    Automatic
# mileage            101000
# fuelType           Diesel
# tax                   240
# mpg                  44.5
# engineSize            1.9
# Name: 10588, dtype: object

# %%
# the lowest mileage
mileage_min = df['mileage'].idxmin()
print(df.loc[mileage_min])
# Out:
# model                  Q7
# year                 2019
# price               69000
# transmission    Automatic
# mileage                 1
# fuelType           Diesel
# tax                   145
# mpg                  30.1
# engineSize            4.0
# Name: 5492, dtype: object

# %%
# sccater plot of the price and mileage based on the type of the model
sns.scatterplot(data=df, x='price',y='mileage', hue='model', alpha=0.7)
plt.show()

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
# sccater plot of the price and mileage based on the fuel type
sns.scatterplot(data=df, x='price',y='mileage', hue='fuelType', alpha=0.7)
plt.show()

# %%
# sccater plot of the price and mpg based on the transmission
sns.scatterplot(data=df, x='price',y='mpg', hue='transmission', alpha=0.7)
plt.show()

# %%
# sccater plot of the price and engin size based on the transmission
sns.scatterplot(data=df, x='price',y='engineSize', hue='transmission', alpha=0.7)
plt.show()

# %%
# correlation metrix
df_corr = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(df_corr, annot=True,)
plt.show()

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
# convert categorical values to numerical
df = df.replace({'transmission': {'Manual': 1, 'Automatic': 2, 'Semi-Auto':3}})

# %%
df['fuelType'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid'], dtype=object)

# %%
# convert categorical values to numerical
df = df.replace({'fuelType': {'Petrol': 1, 'Diesel': 2, 'Hybrid':3}})

# %%
#convert categorical values to numerical using Laber Encoder
le = LabelEncoder()
df['model']= le.fit_transform(df['model'])
# Out:
#        model  year  price transmission  mileage  fuelType  tax   mpg  \
# 0          0  2017  12500       Manual    15735         1  150  55.4
# 1          5  2016  16500    Automatic    36203         2   20  64.2
# 2          0  2016  11000       Manual    29946         1   30  55.4
# 3          3  2017  16800    Automatic    25952         2  145  67.3
# 4          2  2019  17300       Manual     1998         1  145  49.6
# ...      ...   ...    ...          ...      ...       ...  ...   ...
# 10663      2  2020  16999       Manual     4018         1  145  49.6
# 10664      2  2020  16999       Manual     1978         1  150  49.6
# 10665      2  2020  17199       Manual      609         1  150  49.6
# 10666      9  2017  19499    Automatic     8646         1  150  47.9
# 10667      9  2016  15999       Manual    11855         1  150  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# 3             2.0
# 4             1.0
# ...           ...
# ...

# %%
df
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0          0  2017  12500             1    15735         1  150  55.4
# 1          5  2016  16500             2    36203         2   20  64.2
# 2          0  2016  11000             1    29946         1   30  55.4
# 3          3  2017  16800             2    25952         2  145  67.3
# 4          2  2019  17300             1     1998         1  145  49.6
# ...      ...   ...    ...           ...      ...       ...  ...   ...
# 10663      2  2020  16999             1     4018         1  145  49.6
# 10664      2  2020  16999             1     1978         1  150  49.6
# 10665      2  2020  17199             1      609         1  150  49.6
# 10666      9  2017  19499             2     8646         1  150  47.9
# 10667      9  2016  15999             1    11855         1  150  47.9
#
#        engineSize
# 0             1.4
# 1             2.0
# 2             1.4
# 3             2.0
# 4             1.0
# ...

# %%
df['model'].value_counts()
# Out:
# model
# 2     1929
# 9     1417
# 3     1381
# 0     1347
# 4      882
# 10     877
# 8      822
# 5      748
# 11     397
# 25     336
# 6      122
# 7      118
# 12      69
# 17      39
# 14      33
# 15      31
# 16      29
# 13      28
# 19      18
# 23      16
# 20      12
# 24       8
# 22       4
# 21       3
# 1        1
# 18       1
# Name: count, dtype: int64

# %% [markdown]
# # Model Training

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3)

# %%
model = RandomForestRegressor()

model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
pred = model.predict(x_train)

# %%
error_score = r2_score(y_train, pred)
print('R squared Error: ', error_score * 100)
# Out:
# R squared Error:  99.3794493890146

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
from sklearn.model_selection import cross_val_score, KFold

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
scores = cross_val_score(model, x, y, cv=cv, scoring='r2')

# %%
print('Cross-Validation Scores:', scores)
print('Mean R-squared:', scores.mean())
print('Standard Deviation:', scores.std())
# Out:
# Cross-Validation Scores: [0.96358221 0.95775216 0.95724335 0.96058391 0.95948268]
# Mean R-squared: 0.9597288623237447
# Standard Deviation: 0.0022682625588038006

# %%
from sklearn.svm import SVR
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import HuberRegressor, GammaRegressor, RidgeCV, BayesianRidge, Ridge, LinearRegression, ElasticNetCV, LassoCV, LassoLarsIC, LassoLarsCV
from sklearn.multioutput import MultiOutputRegressor
from sklearn.compose import TransformedTargetRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor, HistGradientBoostingRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import PoissonRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import NuSVR

# %%
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
model = LazyRegressor(verbose= 0, regressors=[SVR, BaggingRegressor, NuSVR, RandomForestRegressor, XGBRegressor, GradientBoostingRegressor, ExtraTreesRegressor, AdaBoostRegressor, HistGradientBoostingRegressor, PoissonRegressor, LGBMRegressor, KNeighborsRegressor, DecisionTreeRegressor, MLPRegressor, HuberRegressor, GammaRegressor,  RidgeCV, BayesianRidge, Ridge, TransformedTargetRegressor, LinearRegression, ElasticNetCV, LassoCV, LassoLarsIC, LassoLarsCV])
listofmodels, churnpredictions= model.fit(x_train, x_test , y_train, y_test)
# Out:
#  36%|███▌      | 9/25 [00:33<00:40,  2.53s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 431
# [LightGBM] [Info] Number of data points in the train set: 7467, number of used features: 8
# [LightGBM] [Info] Start training from score 22958.417705
# 100%|██████████| 25/25 [00:47<00:00,  1.90s/it]

# %%
print(listofmodels)
# Out:
#                                Adjusted R-Squared  R-Squared     RMSE  \
# Model
# XGBRegressor                                 0.96       0.96  2266.35
# ExtraTreesRegressor                          0.96       0.96  2360.41
# HistGradientBoostingRegressor                0.96       0.96  2395.35
# LGBMRegressor                                0.96       0.96  2403.52
# RandomForestRegressor                        0.95       0.96  2423.16
# BaggingRegressor                             0.95       0.95  2526.12
# GradientBoostingRegressor                    0.94       0.94  2730.73
# KNeighborsRegressor                          0.94       0.94  2867.89
# DecisionTreeRegressor                        0.93       0.93  3050.69
# PoissonRegressor                             0.89       0.89  3741.53
# RidgeCV                                      0.79       0.79  5277.74
# LassoCV                                      0.79       0.79  5277.75
# ...
